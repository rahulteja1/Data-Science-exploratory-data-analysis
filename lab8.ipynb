# %% [markdown]
# # Lab 8
#
#
# Many of the examples have been adapted from Data100 and J. Canny's course.
#
# **Required Files**
# The imdb.db files (see instructions below on getting this data).

# %% [markdown]
# ## Autograder Setup
#
# For this lab, with the exception of Exercise 1, your answers will not be autograded.
# Also, below you will see new code establishing a condition so that you don't have to worry about commenting out lines of code before submitting.

# %%
import re
import os
if re.search(r'amzn', os.uname().release): 
    GS = True
else: 
    GS = False
GS
# Out:
# False

# %%
if GS==False:
    print("Installing otter:")
    # !pip install otter-grader
# Out:
# Installing otter:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting otter-grader
#   Downloading otter_grader-4.1.0-py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 13.2 MB/s
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from otter-grader) (1.14.1)
# Collecting fica>=0.2.0
#   Downloading fica-0.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (from otter-grader) (1.12.11)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from otter-grader) (1.3.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from otter-grader) (0.3.5.1)
# Collecting jupytext
#   Downloading jupytext-1.14.1-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 39.8 MB/s
# Requirement already satisfied: gspread in /usr/local/lib/python3.7/dist-packages (from otter-grader) (3.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from otter-grader) (7.1.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from otter-grader) (6.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.7/dist-packages (from otter-grader) (0.4.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from otter-grader) (2.23.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from otter-grader) (5.7.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from otter-grader) (1.15.0)
# Collecting python-on-whales
#   Downloading python_on_whales-0.53.0-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.0 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from otter-grader) (2.11.3)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/dist-packages (from fica>=0.2.0->otter-grader) (1.8.6)
# Requirement already satisfied: docutils in /usr/local/lib/python3.7/dist-packages (from fica>=0.2.0->otter-grader) (0.17.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->otter-grader) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->otter-grader) (0.17.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->otter-grader) (0.0.4)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->otter-grader) (1.31.6)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->otter-grader) (1.35.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->otter-grader) (2022.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->otter-grader) (21.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->otter-grader) (1.56.4)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->otter-grader) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->otter-grader) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->otter-grader) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->otter-grader) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->otter-grader) (4.2.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client->otter-grader) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client->otter-grader) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->otter-grader) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->otter-grader) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->otter-grader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->otter-grader) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib->otter-grader) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->otter-grader) (3.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->otter-grader) (2.0.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from jupytext->otter-grader) (0.10.2)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.9 MB/s
# Collecting markdown-it-py<3.0.0,>=1.0.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.1 MB/s
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: typing_extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from markdown-it-py<3.0.0,>=1.0.0->jupytext->otter-grader) (4.1.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->otter-grader) (4.11.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.7/dist-packages (from nbformat->otter-grader) (5.1.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->otter-grader) (4.3.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->otter-grader) (4.13.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->otter-grader) (2.16.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->nbformat->otter-grader) (3.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->otter-grader) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->otter-grader) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->otter-grader) (5.10.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->otter-grader) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->otter-grader) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from python-on-whales->otter-grader) (4.64.1)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from python-on-whales->otter-grader) (0.4.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from python-on-whales->otter-grader) (1.10.2)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx->fica>=0.2.0->otter-grader) (1.4.1)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->fica>=0.2.0->otter-grader) (2.10.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx->fica>=0.2.0->otter-grader) (0.7.12)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx->fica>=0.2.0->otter-grader) (2.2.0)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/dist-packages (from sphinx->fica>=0.2.0->otter-grader) (1.2.4)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx->fica>=0.2.0->otter-grader) (2.6.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib-websupport->sphinx->fica>=0.2.0->otter-grader) (1.1.5)
# Installing collected packages: mdurl, markdown-it-py, mdit-py-plugins, python-on-whales, jupytext, fica, otter-grader
# Successfully installed fica-0.2.0 jupytext-1.14.1 markdown-it-py-2.1.0 mdit-py-plugins-0.3.1 mdurl-0.1.2 otter-grader-4.1.0 python-on-whales-0.53.0

# %%
if GS==False:
    # !wget https://pages.mtu.edu/~lebrown/un5550-f22/labs/lab8/lab8.files.zip
    # !unzip lab8.files.zip
# Out:
# --2022-10-27 03:29:09--  https://pages.mtu.edu/~lebrown/un5550-f22/labs/lab8/lab8.files.zip
# Resolving pages.mtu.edu (pages.mtu.edu)... 141.219.70.232
# Connecting to pages.mtu.edu (pages.mtu.edu)|141.219.70.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797 [application/zip]
# Saving to: ‘lab8.files.zip’
#
# lab8.files.zip      100%[===================>]     797  --.-KB/s    in 0s
#
# 2022-10-27 03:29:09 (83.9 MB/s) - ‘lab8.files.zip’ saved [797/797]
#
# Archive:  lab8.files.zip
#    creating: tests/
#   inflating: tests/q1.py
#   inflating: tests/.DS_Store

# %% [markdown]
# ## Lab Setup

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import getpass
import otter
grader = otter.Notebook()

# %% [markdown]
# For this lab, we will be using SQLite to connect to databases. This is a simple, light-way module, there are of course other modules to interact with databases.
#
# SQLite has a [nice tutorial](https://www.sqlitetutorial.net/) if you want to learn more about database queries and explore additional options.

# %%
import sqlite3

# %% [markdown]
# A couple of things to know about SQLite.  Other database systems such as `MySQL` and `PostgreSQL` use *static typing*, where a column is declared for a specific data type and can only store data of that type.
#
# SQLite uses *dynamic type system*, where a value stored in a column determines its data type, not the column's data type.

# %%
# setup connection to new empty db
conn = sqlite3.connect("testdatabase.db")

# %% [markdown]
# ### Printing out SQL calls and results
#
# We define a function `print_sql(s)` that given an sql query `s` returns the results of the executing.

# %%
def print_sql(c, s):
    print('>', s)
    for result in c.execute(s):
        print(result)
    print()

# %% [markdown]
# We could also use `pandas` `read_sql` function to read in the results of the query to a dataframe to disply.  *Be careful with running this code as it will create the dataframe - for a query that returns many records this could be memory-intensive*

# %%
def pretty_print_sql(c, s):
    print('>', s)
    df = pd.read_sql(s, c)
    display(df)
    return df

# %% [markdown]
# ## Example 1: SQL with a Test DB
#
# Here we will use SQLite connection to a test database.
#
# First, we will create two sample tables to use in the examples.
#
# Create the relational instances in the database.
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/lab6/ex1-tables.png" width="350px">

# %%
conn.executescript("""
DROP TABLE IF EXISTS s;
DROP TABLE IF EXISTS t;

CREATE TABLE s(
    m INTEGER PRIMARY KEY, 
    u TEXT
);

INSERT INTO s VALUES 
    (1, 'W'),
    (2, 'X'),
    (3, 'X'),
    (4, 'Y');

CREATE TABLE t(
    n TEXT PRIMARY KEY, 
    v CHAR
);

INSERT INTO t VALUES 
    ('A', 'X'),
    ('B', 'X'),
    ('C', 'Y'),
    ('D', 'Z');
""");

# %% [markdown]
# We can use this to look at the tables `s` and `t` in undefined order.

# %%
print_sql(conn, 'SELECT * FROM s;')
print_sql(conn, 'SELECT * FROM t;')
# Out:
# > SELECT * FROM s;
# (1, 'W')
# (2, 'X')
# (3, 'X')
# (4, 'Y')
#
# > SELECT * FROM t;
# ('A', 'X')
# ('B', 'X')
# ('C', 'Y')
# ('D', 'Z')

# %%
pretty_print_sql(conn, 'SELECT * FROM t;')
# Out:
# > SELECT * FROM t;
#    n  v
# 0  A  X
# 1  B  X
# 2  C  Y
# 3  D  Z
#    n  v
# 0  A  X
# 1  B  X
# 2  C  Y
# 3  D  Z

# %% [markdown]
# ### Cross Join
#
# Let's know look at performing some of the join operations discussed in class.
#
# First, we will look at the cross join or cross product.
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/lab6/cross-join.png" width="600px">

# %%
print_sql(conn, 'SELECT * FROM s, t;')
# Out:
# > SELECT * FROM s, t;
# (1, 'W', 'A', 'X')
# (1, 'W', 'B', 'X')
# (1, 'W', 'C', 'Y')
# (1, 'W', 'D', 'Z')
# (2, 'X', 'A', 'X')
# (2, 'X', 'B', 'X')
# (2, 'X', 'C', 'Y')
# (2, 'X', 'D', 'Z')
# (3, 'X', 'A', 'X')
# (3, 'X', 'B', 'X')
# (3, 'X', 'C', 'Y')
# (3, 'X', 'D', 'Z')
# (4, 'Y', 'A', 'X')
# (4, 'Y', 'B', 'X')
# (4, 'Y', 'C', 'Y')
# (4, 'Y', 'D', 'Z')

# %%
# Another way to structure our query
print_sql(conn, """
SELECT *
FROM s CROSS JOIN t;
""")
# Out:
# >
# SELECT *
# FROM s CROSS JOIN t;
#
# (1, 'W', 'A', 'X')
# (1, 'W', 'B', 'X')
# (1, 'W', 'C', 'Y')
# (1, 'W', 'D', 'Z')
# (2, 'X', 'A', 'X')
# (2, 'X', 'B', 'X')
# (2, 'X', 'C', 'Y')
# (2, 'X', 'D', 'Z')
# (3, 'X', 'A', 'X')
# (3, 'X', 'B', 'X')
# (3, 'X', 'C', 'Y')
# (3, 'X', 'D', 'Z')
# (4, 'Y', 'A', 'X')
# (4, 'Y', 'B', 'X')
# (4, 'Y', 'C', 'Y')
# (4, 'Y', 'D', 'Z')

# %% [markdown]
# ### Inner Join
#
# Next, look at performing an inner join.
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/lab6/inner-join.png" width="600px">

# %%
# Here are three methods for performing and printint out the inner join
print_sql(conn, 'SELECT * FROM s JOIN t ON s.u = t.v;')
print_sql(conn, 'SELECT * FROM s, t WHERE s.u = t.v;')
pretty_print_sql(conn, 'SELECT * FROM s, t WHERE s.u = t.v;')
# Out:
# > SELECT * FROM s JOIN t ON s.u = t.v;
# (2, 'X', 'A', 'X')
# (2, 'X', 'B', 'X')
# (3, 'X', 'A', 'X')
# (3, 'X', 'B', 'X')
# (4, 'Y', 'C', 'Y')
#
# > SELECT * FROM s, t WHERE s.u = t.v;
# (2, 'X', 'A', 'X')
# (2, 'X', 'B', 'X')
# (3, 'X', 'A', 'X')
# (3, 'X', 'B', 'X')
# (4, 'Y', 'C', 'Y')
#
# > SELECT * FROM s, t WHERE s.u = t.v;
#    m  u  n  v
# 0  2  X  A  X
# 1  2  X  B  X
# 2  3  X  A  X
# 3  3  X  B  X
# 4  4  Y  C  Y
#    m  u  n  v
# 0  2  X  A  X
# 1  2  X  B  X
# 2  3  X  A  X
# 3  3  X  B  X
# 4  4  Y  C  Y

# %% [markdown]
# ### Left Outer Join
#
# Next, let's examine performing a left outer join.
#
# <img src="https://pages.mtu.edu/~lebrown/un5550-f20/lab6/left-outer-join.png" width="600px">

# %%
print_sql(conn, 'SELECT * FROM s LEFT JOIN t ON s.u = t.v')
# Out:
# > SELECT * FROM s LEFT JOIN t ON s.u = t.v
# (1, 'W', None, None)
# (2, 'X', 'A', 'X')
# (2, 'X', 'B', 'X')
# (3, 'X', 'A', 'X')
# (3, 'X', 'B', 'X')
# (4, 'Y', 'C', 'Y')

# %% [markdown]
# ### Other Joins

# %%
print_sql(conn, 'SELECT s.m, s.u, t.n, t.v FROM t LEFT JOIN s ON s.u = t.v;')
print_sql(conn, 'SELECT s.m, s.u, t.n, t.v FROM s LEFT JOIN t ON s.u = t.v UNION '
          'SELECT s.m, s.u, t.n, t.v FROM t LEFT JOIN s ON s.u = t.v;')
# Out:
# > SELECT s.m, s.u, t.n, t.v FROM t LEFT JOIN s ON s.u = t.v;
# (2, 'X', 'A', 'X')
# (3, 'X', 'A', 'X')
# (2, 'X', 'B', 'X')
# (3, 'X', 'B', 'X')
# (4, 'Y', 'C', 'Y')
# (None, None, 'D', 'Z')
#
# > SELECT s.m, s.u, t.n, t.v FROM s LEFT JOIN t ON s.u = t.v UNION SELECT s.m, s.u, t.n, t.v FROM t LEFT JOIN s ON s.u = t.v;
# (None, None, 'D', 'Z')
# (1, 'W', None, None)
# (2, 'X', 'A', 'X')
# (2, 'X', 'B', 'X')
# (3, 'X', 'A', 'X')
# (3, 'X', 'B', 'X')
# (4, 'Y', 'C', 'Y')

# %%
# Close down connection to database
conn.close()

# %% [markdown]
# ## Example 2: IMDB
#
#
# Let's look at some large data files!  We will pull some data from IMDB.
#
#
# ### Database Created
#
# Here is a summary on how the database was created.
#
# **Download data**
#
# The data we are interested is available from [IMDB](https://www.imdb.com/interfaces/)
#
# ```python
# # From https://www.imdb.com/interfaces/
# fetch_and_cache('https://datasets.imdbws.com/title.basics.tsv.gz', 'titles.tsv.gz')
# fetch_and_cache('https://datasets.imdbws.com/name.basics.tsv.gz', 'names.tsv.gz')
# ```
#
# **Unzip files**
#
# ```python
# !gunzip -kf data/titles.tsv.gz
# !gunzip -kf data/names.tsv.gz
# !ls -lh data
# ```
#
# **View files**
#
# If on a Mac, Linux computer or Colab notebook.
#
# ```
# !head -n5 data/titles.tsv
# !head -n5 data/names.tsv
# ```

# %% [markdown]
# **Create the Database**
#
# I have done this for you because it is easier using the command line with `sqlite3`.
#
# * First, removed the `"` that appear in the tab files.
# * Create database using the following commands.
#
# On a Mac/Linux box with sqlite3 v3.8 or higher, run the following commands at the terminal.
#
# ```
# (base) lebrown@lebrown-macbook data$ sqlite3 imdb.db
# SQLite version 3.27.2 2019-02-25 16:06:06
# Enter ".help" for usage hints.
# sqlite> .mode tabs
# sqlite> .import titles.tsv titles
# sqlite> .import names.tsv names
# sqlite> ^D
# ```

# %% [markdown]
# ### Download the Database
#
# The `imdb.db` database is available for you to download on [Kaggle](https://www.kaggle.com/).
#
# You have already created your Kaggle account and can again use your API to access the data.

# %% [markdown]
# #### Method 1:
# Copy and paste the key information (does not upload your key information to the Drive).

# %%
from getpass import getpass

if GS==False:
    os.environ['KAGGLE_USERNAME'] = getpass("Enter Kaggle Username: ")
    os.environ['KAGGLE_KEY'] = getpass("Enter Kaggle API Key: ")
# Out:
# Enter Kaggle Username: ··········
# Enter Kaggle API Key: ··········

# %% [markdown]
# #### Method 2
#
# Load `kaggle.json` to Colab directory (file is destroyed when sevice is disconnected).  This method relys on Google's security for safely storing and protecting your data.

# %%
# from google.colab import files

# if GS==False:
#     uploaded = files.upload()

# %%
# import json

# if GS==False:
#     with open("kaggle.json") as f:
#         keys = json.load(f)

#     os.environ['KAGGLE_USERNAME'] = keys["username"] # username from the json file
#     os.environ['KAGGLE_KEY'] = keys["key"] # key from the json file

# %% [markdown]
# #### Download the Data

# %%
if GS==False:
    # !kaggle datasets download -d lebrown/un5550-imdb # api copied from kaggle
# Out:
# Downloading un5550-imdb.zip to /content
#  98% 468M/479M [00:03<00:00, 135MB/s]
# 100% 479M/479M [00:03<00:00, 128MB/s]

# %%
import zipfile

if GS==False:
    # Will unzip the files so that you can see them..
    with zipfile.ZipFile("un5550-imdb.zip","r") as z:
        z.extractall(".")

# %% [markdown]
# You now have the `imdb.db` database available to you.

# %%
if GS==False:
    conn = sqlite3.connect("imdb.db")

# %% [markdown]
# ## Exercise 1
#
# Let's look at just the first 10 entries from the `titles` relation.
#
# Your solution should be of the form:
# ```
# q1df = pretty_print_sql(<conn>, <query>)
# ```

# %%
if GS==False:
    q1df = pretty_print_sql(conn, "SELECT * FROM titles LIMIT 10;") 
else: 
    q1df = 1
# Out:
# > SELECT * FROM titles LIMIT 10;
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     movie                                   Miss Jerry
# 9  tt0000010     short                          Leaving the Factory
#
#                                  originalTitle isAdult startYear endYear  \
# 0                                   Carmencita       0      1894      \N
# 1                       Le clown et ses chiens       0      1892      \N
# 2                               Pauvre Pierrot       0      1892      \N
# 3                                  Un bon bock       0      1892      \N
# 4                             Blacksmith Scene       0      1893      \N
# 5                            Chinese Opium Den       0      1894      \N
# 6  Corbett and Courtney Before the Kinetograph       0      1894      \N
# 7       Edison Kinetoscopic Record of a Sneeze       0      1894      \N
# 8                                   Miss Jerry       0      1894      \N
# 9          La sortie de l'usine Lumière à Lyon       0      1895      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             12           Animation,Short
# 4              1              Comedy,Short
# 5              1                     Short
# 6              1               Short,Sport
# 7              1         Documentary,Short
# 8             45                   Romance
# 9              1         Documentary,Short

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Exercise 2
#
# While we know the structure of the tables from IMDB, see how this info is laid out.
#
# That is, show the tables in the database and their structure (i.e., what fields-types they have)
#
# Use the `conn.execute(...)` function rather than the `pretty_print_sql(...)` function.
#
# You answer should look like:
#
#     CREATE TABLE titles(
#       "tconst" TEXT,
#       ...

# %%
q2str = ''

for exp in conn.execute("SELECT sql FROM sqlite_master;"):
    print(exp[0])
print(q2str)
# Out:
# CREATE TABLE titles(
#   "tconst" TEXT,
#   "titleType" TEXT,
#   "primaryTitle" TEXT,
#   "originalTitle" TEXT,
#   "isAdult" TEXT,
#   "startYear" TEXT,
#   "endYear" TEXT,
#   "runtimeMinutes" TEXT,
#   "genres" TEXT
# )
# CREATE TABLE names(
#   "nconst" TEXT,
#   "primaryName" TEXT,
#   "birthYear" TEXT,
#   "deathYear" TEXT,
#   "primaryProfession" TEXT,
#   "knownForTitles" TEXT
# )

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ## Exercise 3
#
# Write a query to return the movies where the starting year > 2005.
#
# Your solution should be of the form:
# ```
# pretty_print_sql(<conn>, <query>)
# ```
#
# Display all fields of the appropriate table.
#
# Make sure to exclude records that are missing a starting year value (encoded as '\N')
#
# Limit your query to 10 records.

# %%
q3df = pretty_print_sql(conn, "SELECT * FROM titles WHERE startYear>2005 AND startYear IS NOT '\\N' LIMIT 10;")
# Out:
# > SELECT * FROM titles WHERE startYear>2005 AND startYear IS NOT '\N' LIMIT 10;
#       tconst titleType                               primaryTitle  \
# 0  tt0013620     short                               Sol y sombra
# 1  tt0016906     movie                                 Frivolinas
# 2  tt0055769     short                       La bague du roi Koda
# 3  tt0060366     short                       A Embalagem de Vidro
# 4  tt0062336     movie  El Tango del Viudo y Su Espejo Deformante
# 5  tt0065047     short                      The Sun's Gonna Shine
# 6  tt0065392     movie                         Bucharest Memories
# 7  tt0068943     short           Between Wrocław and Zielona Góra
# 8  tt0069049     movie                 The Other Side of the Wind
# 9  tt0072306     movie               Toula ou Le génie des eaux *
#
#                                originalTitle isAdult startYear endYear  \
# 0                               Sol y sombra       0      2020      \N
# 1                                 Frivolinas       0      2014      \N
# 2                       La bague du roi Koda       0      2017      \N
# 3                       A Embalagem de Vidro       0      2020      \N
# 4  El Tango del Viudo y Su Espejo Deformante       0      2020      \N
# 5                      The Sun's Gonna Shine       0      2014      \N
# 6                       Amintiri bucurestene       0      2020      \N
# 7           Miedzy Wroclawiem a Zielona Góra       0      2010      \N
# 8                 The Other Side of the Wind       0      2018      \N
# 9               Toula ou Le génie des eaux *       0      2017      \N
#
#   runtimeMinutes                   genres
# 0             40              Drama,Short
# 1             80           Comedy,Musical
# 2             24                    Short
# 3             11        Documentary,Short
# 4             70                    Drama
# 5             10  Documentary,Music,Short
# 6             \N              Documentary
# 7             11        Documentary,Short
# 8            122                    Drama
# 9             90                    Drama

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ## Exercise 4
#
# Write a query to return fantasy, TV shows starting in 2007 with a 43 minute running time.
#
# Your solution should be of the form:
# ```
# pretty_print_sql(<conn>, <query>)
# ```
#
# Display all fields of the appropriate table.
#
# Limit your query to return 10 records.

# %%
q4df = pretty_print_sql(conn, """SELECT * FROM titles 
                                WHERE genres='Fantasy' AND 
                                titleType LIKE 'tv%' AND 
                                startYear >= 2007 AND
                                runtimeMinutes = 43 LIMIT 10 ;""")
# Out:
# > SELECT * FROM titles
#                                 WHERE genres='Fantasy' AND
#                                 titleType LIKE 'tv%' AND
#                                 startYear >= 2007 AND
#                                 runtimeMinutes = 43 LIMIT 10 ;
#        tconst     titleType                   primaryTitle  \
# 0  tt11766644  tvMiniSeries                    Untold Love
# 1   tt2956310     tvEpisode                      Mr Fluffy
# 2   tt5210250     tvEpisode              Corporate Lessons
# 3   tt5691044     tvEpisode                     Mr. Fluffy
# 4   tt5697002     tvEpisode                     Lady Mayne
# 5   tt6289296      tvSeries  Ghost Dragon of Cold Mountain
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                    Untold Love       0      2021      \N             43
# 1                      Mr Fluffy       0      2013      \N             43
# 2              Corporate Lessons       0      2015      \N             43
# 3                     Mr. Fluffy       0      2015      \N             43
# 4                     Lady Mayne       0      2015      \N             43
# 5  Ghost Dragon of Cold Mountain       0      2014    2015             43
#
#     genres
# 0  Fantasy
# 1  Fantasy
# 2  Fantasy
# 3  Fantasy
# 4  Fantasy
# 5  Fantasy

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Example 3 -  Add new table for Dramas
#
# Python allows for string substition with the following expression (new in Python 3.6)

# %%
# Python string substitution 
who, where = 'Laura', 'here'
temp = f"{who} is {where}"
temp
# Out:
# 'Laura is here'

# %% [markdown]
# We will use this to select out information about drama movies. Then, create a new table titled `dramas` that we can use in the following questions.

# %%
key = 'tconst'
title = 'primaryTitle'
time = 'runtimeMinutes'
year = 'startYear'
adult = 'isAdult'
kind = 'titleType'

select_drama = f'''
    SELECT {key} AS id,
           {title} AS title, 
           CAST({time} AS int) AS time, 
           CAST({year} AS int) AS year
    FROM titles
    WHERE genres LIKE '%Drama%' AND
          {year} > 1900 AND 
          {year} < 2019 AND
          {adult} = '0' AND
          {kind} = 'movie' AND
          time > 60
    '''
conn.executescript(f'''
    DROP TABLE IF EXISTS dramas;
    CREATE TABLE dramas AS {select_drama};
    ''')

# %% [markdown]
# Now we can query this table `dramas`

# %%
ex3 = pretty_print_sql(conn, 'SELECT * FROM dramas ORDER BY year DESC LIMIT 10')
# Out:
# > SELECT * FROM dramas ORDER BY year DESC LIMIT 10
#            id                              title  time  year
# 0   tt0069049         The Other Side of the Wind   122  2018
# 1   tt0192528                      Heaven & Hell   104  2018
# 2   tt0276568                 To Chase a Million    97  2018
# 3   tt0328810                            My Land   102  2018
# 4   tt0360556                     Fahrenheit 451   100  2018
# 5   tt0365545                 Nappily Ever After    98  2018
# 6   tt0427543            A Million Little Pieces   113  2018
# 7   tt0825334  Caravaggio and My Mother the Pope    90  2018
# 8   tt0972544                         Back Roads   101  2018
# 9  tt10004396          When I Became a Butterfly   102  2018

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Exercise 5
#
# For this question you will plot the mean running time of dramas for each year.
#
# Use the `pd.read_sql` command frame your query, then use the DataFrame returned to make the plot.

# %%
q5df = pd.read_sql("SELECT time,year FROM dramas;",con = conn)
q5df

years = q5df.groupby('year')['time'].mean().keys()
mean_run_time = q5df.groupby('year')['time'].mean()

plt.figure(figsize=(10,8))
plt.plot(years,mean_run_time);

plt.xlabel('years');
plt.ylabel('mean_run_time');
plt.title(' mean_run_time vs. years');
# ...

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ## Exercise 6
#
#
# The information above to make the plot (mean running time of the dramas for each year), you will now calculate using a query.
#
# Your query should return two attributes: year and average time.
#
# Your solution should be of the form:
# ```
# pretty_print_sql(<conn>, <query>)
# ```

# %%
q6df = pretty_print_sql(conn, "SELECT year, AVG(time) as average_time FROM dramas GROUP BY year LIMIT 10;")
# Out:
# > SELECT year, AVG(time) as average_time FROM dramas GROUP BY year LIMIT 10;
#    year  average_time
# 0  1906     70.000000
# 1  1910     82.333333
# 2  1911     75.500000
# 3  1912     98.000000
# 4  1913     92.428571
# 5  1914    104.527778
# 6  1915     94.970588
# 7  1916     86.648148
# 8  1917     85.047619
# 9  1918     81.766234

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Example 4 -  Examine `names` table
#
# Let's switch gears to consider the `names` table.

# %%
pd.read_sql('SELECT DISTINCT * FROM names LIMIT 10;', conn)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
# 5  nm0000006   Ingrid Bergman      1915      1982
# 6  nm0000007  Humphrey Bogart      1899      1957
# 7  nm0000008    Marlon Brando      1924      2004
# 8  nm0000009   Richard Burton      1925      1984
# 9  nm0000010     James Cagney      1899      1986
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
# 5          actress,soundtrack,producer
# 6            actor,soundtrack,producer
# 7            actor,soundtrack,director
# 8            actor,soundtrack,producer
# 9            actor,soundtrack,director
#
#                             knownForTitles
# 0  tt0053137,tt0031983,tt0050419,tt0072308
# 1  tt0038355,tt0071877,tt0117057,tt0037382
# 2  tt0059956,tt0054452,tt0057345,tt0049189
# 3  tt0078723,tt0072562,tt0080455,tt0077975
# 4  tt0083922,tt0060827,tt0050986,tt0050976
# 5  tt0038787,tt0036855,tt0034583,tt0038109
# 6  tt0034583,tt0040897,tt0043265,tt0037382
# 7  tt0078788,tt0068646,tt0047296,tt0070849
# 8  tt0057877,tt0059749,tt0061184,tt0087803
# 9  tt0035575,tt0042041,tt0031867,tt0029870

# %% [markdown]
# We can create a DataFrame of selected information and people (using a query `select_actors`).  Only consider actors and actresses, born after 1950, list only their first known movie id.

# %%
name = 'primaryName'
known = 'knownForTitles'
profession = 'primaryProfession'
born = 'birthYear'

select_actors = f'''
    SELECT DISTINCT {name} AS name, 
           CAST({born} AS int) AS born,
           SUBSTR({known}, 0, INSTR({known}, ',')) AS movie_id,
           CASE WHEN {profession} LIKE '%actor%' THEN 'actor' 
                WHEN {profession} LIKE '%actress%' THEN 'actress'   
                END AS profession
    FROM names
    WHERE {profession} LIKE '%act%' AND
          born > 1950
    '''
pd.read_sql(f'{select_actors} LIMIT 10', conn)
# Out:
#                 name  born   movie_id profession
# 0  Margaux Hemingway  1954  tt0102122    actress
# 1            Li Gong  1965  tt0397535    actress
# 2     Elena Koreneva  1953  tt7529350    actress
# 3          Brad Pitt  1963  tt0114746      actor
# 4   Gillian Anderson  1968  tt2294189    actress
# 5    Pamela Anderson  1967  tt0426592    actress
# 6   Jennifer Aniston  1969  tt0108778    actress
# 7  Patricia Arquette  1968  tt1065073    actress
# 8     Rowan Atkinson  1955  tt0110357      actor
# 9        Dan Aykroyd  1952  tt0080455      actor

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Exercise 7
#
# Create a new table `dramatics` that joins the `select_actors` (from query above) with the `dramas` table by `movie_id` and returns the actor's `name`, `profession`, year `born` as well as their movie they are known for `title` and `year` it was released.
#
#
# Consider the `select_actors` query as a subquery.  Take a look at the information here on subqueries and the examples:
# https://www.sqlitetutorial.net/sqlite-subquery/
# https://www.w3resource.com/sqlite/sqlite-subqueries.php
#
# Then, query the new table `dramatics` and return 10 sorted by ascending year born (all attributes).

# %%
select_dramatics = f'''  
DROP TABLE IF EXISTS dramatics;
CREATE TABLE dramatics AS 
    SELECT name, profession, born, title, year
    FROM ({select_actors}) as temp
    JOIN dramas ON
    temp.movie_id = dramas.id
'''

conn.executescript(select_dramatics)

q7df = pretty_print_sql(conn, "SELECT * FROM dramatics ORDER BY born ASC LIMIT 10")
# Out:
# > SELECT * FROM dramatics ORDER BY born ASC LIMIT 10
#                 name profession  born                     title  year
# 0  Dominique Vincent    actress  1951     Il prigioniero del re  1954
# 1      Susie Mathers    actress  1951           This Is My Love  1954
# 2     Columba Powell      actor  1951  Pursuit of the Graf Spee  1956
# 3         Peter Pike      actor  1951          It Takes a Thief  1960
# 4       Donald Losby      actor  1951           Tower of London  1962
# 5        Alan Howard      actor  1951           Ladybug Ladybug  1963
# 6       Ion Bocancea      actor  1951               Camera alba  1965
# 7       Paul O'Keefe      actor  1951            The Daydreamer  1966
# 8        Antony Paul      actor  1951               Herostratus  1967
# 9        Kumi Hayase    actress  1951        Rebellion of Japan  1967

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Example 5 - Add new tables
#
# Note, both the `titles` and `names` tables have fields that contains array of items, e.g., `names`- `knownForTitles`, `names` - `primaryProfession`, `titles` - `genres`, etc.
#
# We saw in Example 3 and Exercise 5 we can still extract rows that match a certain genre, e.g., "%Drama%".  Or, in Example 4, we can select the first title that an person is known for.
#
# However, classic relational database design should not contain lists of items in a field.  Therefore, we will expand out these fields to new tables.
#
# First, we will add a new table `name_to_title` that matches each name id `nconst` with the title id `tconst`.

# %%
cursor = conn.cursor()
cursor.execute("""Select * from names""")
all_data = cursor.fetchall()

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS name_to_title
                    (nconst TEXT,
                    tconst TEXT)""")

# %%
for single_data in all_data:
    person  = single_data[5].split(",")
    for single_data2 in person:
        cursor.execute("INSERT INTO name_to_title VALUES(:nconst,:tconst)", 
                       { "nconst": single_data[0], "tconst": single_data2 })
conn.commit()

# %%
print_sql(conn, 'SELECT * FROM name_to_title LIMIT 10;')
# Out:
# > SELECT * FROM name_to_title LIMIT 10;
# ('nm0000001', 'tt0053137')
# ('nm0000001', 'tt0031983')
# ('nm0000001', 'tt0050419')
# ('nm0000001', 'tt0072308')
# ('nm0000002', 'tt0038355')
# ('nm0000002', 'tt0071877')
# ('nm0000002', 'tt0117057')
# ('nm0000002', 'tt0037382')
# ('nm0000003', 'tt0059956')
# ('nm0000003', 'tt0054452')

# %% [markdown]
# We can also separate out the list of professions to a separate table `name_to_profession`.

# %%
cursor = conn.cursor()
cursor.execute("""Select * from names""")
all_data = cursor.fetchall()

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS name_to_profession
                    (nconst TEXT,
                    profession TEXT)""")

# %%
for single_data in all_data:
    person  = single_data[4].split(",")
    for single_data2 in person:
        cursor.execute("INSERT INTO name_to_profession VALUES(:nconst,:prof)", 
                       { "nconst": single_data[0], "prof": single_data2 })
conn.commit()

# %%
print_sql(conn, 'SELECT * FROM name_to_profession LIMIT 10;')
# Out:
# > SELECT * FROM name_to_profession LIMIT 10;
# ('nm0000001', 'soundtrack')
# ('nm0000001', 'actor')
# ('nm0000001', 'miscellaneous')
# ('nm0000002', 'actress')
# ('nm0000002', 'soundtrack')
# ('nm0000003', 'actress')
# ('nm0000003', 'soundtrack')
# ('nm0000003', 'music_department')
# ('nm0000004', 'actor')
# ('nm0000004', 'soundtrack')

# %%
# Clean up variables (reduce memory usage)
del all_data

# %% [markdown]
# ## Example 6 -  Age of Actors in Films
#
# We are now interested in looking at the age of actors (both actors and actresses) in movies.
#
# We can start to look at this by first examining the actors and actresses.

# %%
ex6 = pretty_print_sql(conn, """
SELECT n.nconst, 
    n.primaryName AS name, 
    n.birthYear AS born,
    ntp.profession
FROM names n, name_to_profession ntp
WHERE 
    n.nconst = ntp.nconst AND
    (ntp.profession = 'actor' OR ntp.profession = 'actress') 
LIMIT 10;
""")
# Out:
# >
# SELECT n.nconst,
#     n.primaryName AS name,
#     n.birthYear AS born,
#     ntp.profession
# FROM names n, name_to_profession ntp
# WHERE
#     n.nconst = ntp.nconst AND
#     (ntp.profession = 'actor' OR ntp.profession = 'actress')
# LIMIT 10;
#       nconst             name  born profession
# 0  nm0000001     Fred Astaire  1899      actor
# 1  nm0000002    Lauren Bacall  1924    actress
# 2  nm0000003  Brigitte Bardot  1934    actress
# 3  nm0000004     John Belushi  1949      actor
# 4  nm0000005   Ingmar Bergman  1918      actor
# 5  nm0000006   Ingrid Bergman  1915    actress
# 6  nm0000007  Humphrey Bogart  1899      actor
# 7  nm0000008    Marlon Brando  1924      actor
# 8  nm0000009   Richard Burton  1925      actor
# 9  nm0000010     James Cagney  1899      actor

# %% [markdown]
# Next we want to examine the age of actors in different movies.  This means we need to combine the `actor` information with the date of the films.
#
# We can use a [Common Table Expression](https://www.essentialsql.com/introduction-common-table-expressions-ctes/).

# %%
ex6b = pretty_print_sql(conn, """
WITH actors AS (
    SELECT n.nconst, 
        n.primaryName AS name, 
        n.birthYear AS born,
        ntp.profession
    FROM names n, name_to_profession ntp
    WHERE 
        n.nconst = ntp.nconst AND
        (ntp.profession = 'actor' OR ntp.profession = 'actress') 
    )
SELECT 
    a.nconst,
    a.name,
    t.startYear - a.born AS age,
    t.startYear,
    t.primaryTitle,
    a.profession
FROM 
    actors a, 
    name_to_title nt, 
    titles t
WHERE 
    a.nconst = nt.nconst AND nt.tconst = t.tconst 
LIMIT 10;
""")
# Out:
# >
# WITH actors AS (
#     SELECT n.nconst,
#         n.primaryName AS name,
#         n.birthYear AS born,
#         ntp.profession
#     FROM names n, name_to_profession ntp
#     WHERE
#         n.nconst = ntp.nconst AND
#         (ntp.profession = 'actor' OR ntp.profession = 'actress')
#     )
# SELECT
#     a.nconst,
#     a.name,
#     t.startYear - a.born AS age,
#     t.startYear,
#     t.primaryTitle,
#     a.profession
# FROM
#     actors a,
#     name_to_title nt,
#     titles t
# WHERE
#     a.nconst = nt.nconst AND nt.tconst = t.tconst
# LIMIT 10;
#       nconst             name  age startYear  \
# 0  nm0000001     Fred Astaire   40      1939
# 1  nm0000001     Fred Astaire   58      1957
# 2  nm0000001     Fred Astaire   60      1959
# 3  nm0000001     Fred Astaire   75      1974
# 4  nm0000002    Lauren Bacall   20      1944
# 5  nm0000002    Lauren Bacall   22      1946
# 6  nm0000002    Lauren Bacall   50      1974
# 7  nm0000002    Lauren Bacall   72      1996
# 8  nm0000003  Brigitte Bardot   22      1956
# 9  nm0000003  Brigitte Bardot   26      1960
#
#                            primaryTitle profession
# 0  The Story of Vernon and Irene Castle      actor
# 1                            Funny Face      actor
# 2                          On the Beach      actor
# 3                  The Towering Inferno      actor
# 4                  To Have and Have Not    actress
# 5                         The Big Sleep    actress
# 6          Murder on the Orient Express    actress
# 7              The Mirror Has Two Faces    actress
# 8              ...And God Created Woman    actress
# 9                             La Vérité    actress

# %% [markdown]
# We can use "format strings" to plug into the queries.

# %%
actors_query = """
SELECT n.nconst, 
    n.primaryName AS name, 
    n.birthYear AS born,
    ntp.profession
FROM names n, name_to_profession ntp
WHERE 
    n.nconst = ntp.nconst AND
    (ntp.profession = 'actor' OR ntp.profession = 'actress') 
"""

# %%
ex6c = pretty_print_sql(conn, f"""
WITH actors AS ({actors_query})
SELECT 
    a.nconst,
    a.name,
    t.startYear - a.born AS age,
    t.startYear,
    t.primaryTitle,
    a.profession
FROM 
    actors a, 
    name_to_title nt, 
    titles t
WHERE 
    a.nconst = nt.nconst AND nt.tconst = t.tconst 
LIMIT 10;
""")
# Out:
# >
# WITH actors AS (
# SELECT n.nconst,
#     n.primaryName AS name,
#     n.birthYear AS born,
#     ntp.profession
# FROM names n, name_to_profession ntp
# WHERE
#     n.nconst = ntp.nconst AND
#     (ntp.profession = 'actor' OR ntp.profession = 'actress')
# )
# SELECT
#     a.nconst,
#     a.name,
#     t.startYear - a.born AS age,
#     t.startYear,
#     t.primaryTitle,
#     a.profession
# FROM
#     actors a,
#     name_to_title nt,
#     titles t
# WHERE
#     a.nconst = nt.nconst AND nt.tconst = t.tconst
# LIMIT 10;
#       nconst             name  age startYear  \
# 0  nm0000001     Fred Astaire   40      1939
# 1  nm0000001     Fred Astaire   58      1957
# 2  nm0000001     Fred Astaire   60      1959
# 3  nm0000001     Fred Astaire   75      1974
# 4  nm0000002    Lauren Bacall   20      1944
# 5  nm0000002    Lauren Bacall   22      1946
# 6  nm0000002    Lauren Bacall   50      1974
# 7  nm0000002    Lauren Bacall   72      1996
# 8  nm0000003  Brigitte Bardot   22      1956
# 9  nm0000003  Brigitte Bardot   26      1960
#
#                            primaryTitle profession
# 0  The Story of Vernon and Irene Castle      actor
# 1                            Funny Face      actor
# 2                          On the Beach      actor
# 3                  The Towering Inferno      actor
# 4                  To Have and Have Not    actress
# 5                         The Big Sleep    actress
# 6          Murder on the Orient Express    actress
# 7              The Mirror Has Two Faces    actress
# 8              ...And God Created Woman    actress
# 9                             La Vérité    actress

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Exercise 8
#
# Let's calculate the average age of an actor (actors and actresses) in a movie (the `startYear` for a movie - when an actor was born `birthYear`), for all actors born after 1900.
#
# Your answer should be a single entry in a DataFrame.

# %%
actor_query = f'''WITH actors AS ({actors_query})
SELECT 
    AVG(t.startYear - a.born) AS age
FROM 
    actors a, 
    name_to_title nt, 
    titles t
WHERE 
    a.nconst = nt.nconst AND nt.tconst = t.tconst AND a.born > 1900
LIMIT 10;
    '''   # define your query


q8df = pretty_print_sql(conn,actor_query)
# Out:
# > WITH actors AS (
# SELECT n.nconst,
#     n.primaryName AS name,
#     n.birthYear AS born,
#     ntp.profession
# FROM names n, name_to_profession ntp
# WHERE
#     n.nconst = ntp.nconst AND
#     (ntp.profession = 'actor' OR ntp.profession = 'actress')
# )
# SELECT
#     AVG(t.startYear - a.born) AS age
# FROM
#     actors a,
#     name_to_title nt,
#     titles t
# WHERE
#     a.nconst = nt.nconst AND nt.tconst = t.tconst AND a.born > 1900
# LIMIT 10;
#            age
# 0  1673.373891

# %% [markdown]
# <!-- END QUESTION -->
#
# Note, you may get a value that doesn't really make sense.  We will try to fix this in the Bonus Question.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Bonus Question 1
#
# Let's dive into the results. Because these queries can take a while, let's pull this information from Question 8 into a DataFrame, but returning information like `name`, `age`, `title.startYear`, `t.primaryTitle`.
#
# Use `df = pd.read_sql("query", conn)`

# %%
# conn.executescript(f'''
#     DROP TABLE IF EXISTS select_actors;
#     CREATE TABLE select_actors AS {select_actors};
#     ''');

# actor_ = """
# WITH actors AS (SELECT * FROM 
# actors_query),
# SELECT name, age, startYear, primaryTitle
# FROM (
# SELECT 
#     a.nconst,
#     a.name,
#     (t.startYear - a.born) AS age,
#     t.startYear,
#     t.primaryTitle,
#     a.profession
# FROM 
#     actors a, 
#     name_to_title nt, 
#     titles t
# WHERE 
#     a.nconst = nt.nconst AND nt.tconst = t.tconst
#     AND a.born > 1900);
# """

# df = pd.read_sql(actor_, conn)

# %%
# df.age.mean()

# %%
# df.sort_values("age").head()

# %% [markdown]
# Try to solve issues the "\N" missing values introduce.
#
# You can through your DataFrame `df` to splot different potential issues.
#
# Considering only movies with a start year between 1940 and 2020, list all the issues the missing values that must be considered and accounted for.

# %% [markdown]
# * ...
# * ...

# %% [markdown]
# Rewrite your query to account for these issues and produce a DataFrame that has for each year of film, the profession ('actor' and 'actress'), the average age of profession, and the number ("count") of the profession.

# %%
# actor_query = '''...'''   # define your query

# df = pd.read_sql(...)
# df.head(20)

# %% [markdown]
# <!-- END QUESTION -->

# %%
# Close your DB connection 
conn.close()
